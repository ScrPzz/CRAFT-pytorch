# %%
# https://github.com/clovaai/deep-text-recognition-benchmark#download-lmdb-dataset-for-traininig-and-evaluation-from-here
# https://github.com/clovaai/CRAFT-pytorch

# %%
import json
import os
import numpy as np
import urllib.parse
from PIL import Image
import cv2
import types
from collections import namedtuple
import shutil

# %% [markdown]
# ### paths

# %%
import os

def list_files(dir):
    r = []
    for root, dirs, files in os.walk(dir):
        for name in files:
            r.append(os.path.abspath(os.path.join(root, name)))
    return r

# %%
imgs_paths=list_files('./test_images/post_imgs/TEST/')

# %%
imgs_paths
# Out:
# ['/home/atogni/Desktop/ocr_gradient/craft_model/test_images/post_imgs/TEST/Ca-GHMas63y.jpg',
#  '/home/atogni/Desktop/ocr_gradient/craft_model/test_images/post_imgs/TEST/CezOjxXOalw_1.jpg',
#  '/home/atogni/Desktop/ocr_gradient/craft_model/test_images/post_imgs/TEST/Cb8fMmqFr6u.jpg',
#  '/home/atogni/Desktop/ocr_gradient/craft_model/test_images/post_imgs/TEST/bboxes_infos.json',
#  '/home/atogni/Desktop/ocr_gradient/craft_model/test_images/post_imgs/TEST/CcOnQYnOcmB.jpg',
#  '/home/atogni/Desktop/ocr_gradient/craft_model/test_images/post_imgs/TEST/CezOjxXOalw_4.jpg',
#  '/home/atogni/Desktop/ocr_gradient/craft_model/test_images/post_imgs/TEST/Cb_FuDsFwyJ_0.jpg',
#  '/home/atogni/Desktop/ocr_gradient/craft_model/test_images/post_imgs/TEST/CY9MkcNOuHg.jpg',
#  '/home/atogni/Desktop/ocr_gradient/craft_model/test_images/post_imgs/TEST/CH_JQugBNjc_2.jpg',
#  '/home/atogni/Desktop/ocr_gradient/craft_model/test_images/post_imgs/TEST/Cb_FuDsFwyJ_2.jpg',
#  '/home/atogni/Desktop/ocr_gradient/craft_model/test_images/post_imgs/TEST/CcqKL8kON2G_0.jpg',
#  '/home/atogni/Desktop/ocr_gradient/craft_model/test_images/post_imgs/TEST/craft_mlt_25k.pth',
#  '/home/atogni/Desktop/ocr_gradient/craft_model/test_images/post_imgs/TEST/Cb_FuDsFwyJ_3.jpg',
#  '/home/atogni/Desktop/ocr_gradient/craft_model/test_images/post_imgs/TEST/Cb_FuDsFwyJ_1.jpg',
#  '/home/atogni/Desktop/ocr_gradient/craft_model/test_images/post_imgs/TEST/CH_JQugBNjc_1.jpg',
#  '/home/atogni/Desktop/ocr_gradient/craft_model/test_images/post_imgs/TEST/CcqKL8kON2G/CcqKL8kON2G_3.jpg',
#  '/home/atogni/Desktop/ocr_gradient/craft_model/test_images/post_imgs/TEST/CcqKL8kON2G/CcqKL8kON2G_1.jpg',
#  '/home/atogni/Desktop/ocr_gradient/craft_model/test_images/post_imgs/TEST/CcqKL8kON2G/CcqKL8kON2G_4.jpg',
#  '/home/atogni/Desktop/ocr_gradient/craft_model/test_images/post_imgs/TEST/CcqKL8kON2G/CcqKL8kON2G_2.jpg',
#  '/home/atogni/Desktop/ocr_gradient/craft_model/test_images/post_imgs/TEST/CZMvd-LuNFJ/CZMvd-LuNFJ_2.jpg',
#  '/home/atogni/Desktop/ocr_gradient/craft_model/test_images/post_imgs/TEST/CZMvd-LuNFJ/CZMvd-LuNFJ_3.jpg',
#  '/home/atogni/Desktop/ocr_gradient/craft_model/test_images/post_imgs/TEST/CZMvd-LuNFJ/CZMvd-LuNFJ_0.jpg',
#  '/home/atogni/Desktop/ocr_gradient/craft_model/test_images/post_imgs/TEST/CZMvd-LuNFJ/CZMvd-LuNFJ_1.jpg']

# %%
try:
    os.mkdir('./output')
except:
    pass

# %%
for p in imgs_paths:
    shutil.copyfile(p, f"./output/{p.split('/')[-1]}")

# %%
output_folder='./output/'
craft_results_folder='./results/'
bboxes_path = f"{b_path}bboxes_infos.json"

# %%
with open(bboxes_path) as f:
    boxes=json.load(f)

# %%
Image.open(imgs_paths[0])
orig_img=Image.open(imgs_paths[0])
width, height= orig_img.size

# %%
Image.open(imgs_paths[0])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x1079>

# %%
 def show_cv_to_pil(cv_img):
        "Auxiliary function to fix opencv.show() not working on linux"
        cv_img = cv2.cvtColor(cv_img, cv2.COLOR_BGR2RGB)
        im_pil = Image.fromarray(cv_img)
        im_pil.show()


class BoxesEngine():
    
    def extract_area_of_4boxes_list(self, list_bboxes):
        "Extract area of a list of boxes in 4 vertex format"
        a=0.0
        for box in list_bboxes:
            dx=round(max(box[0][0], box[1][0]) - min(box[0][0], box[1][0]), 2)
            dy=round(max(box[0][1], box[3][1]) - min(box[0][1], box[3][1]), 2)
            a+=dx*dy
        return round(a, 0)
    
    def extract_area_of_tl_br_box_list(self,tl_br_tup_lst):
        "Calculate area of a tl_dr box list"
        a=0.0
        for tl_br_tup in tl_br_tup_lst:
            dx=round(max(tl_br_tup[0][0], tl_br_tup[1][0]) - min(tl_br_tup[0][0], tl_br_tup[1][0]), 0)
            dy=round(max(tl_br_tup[0][1], tl_br_tup[1][1]) - min(tl_br_tup[0][1], tl_br_tup[1][1]), 0)
            a+= int(dx*dy)
        return a

    def _4bbox_to_tl_br(self,box_vertices):
        """Transform 4-vertex box to named tuple:
        Box = namedtuple("Box", "top_left bottom_right dx dy")"""

        tl=[min([v[0] for v in box_vertices]), min([v[1] for v in box_vertices])]
        br=[max([v[0] for v in box_vertices]), max([v[1] for v in box_vertices])]
        dx=round(max(box_vertices[0][0], box_vertices[1][0]) - min(box_vertices[0][0], box_vertices[1][0]), 2)
        dy=round(max(box_vertices[0][1], box_vertices[3][1]) - min(box_vertices[0][1], box_vertices[3][1]), 2)

        return Box(tl, br, dx, dy)


    def tl_br_list_to_centers(self,tl_dr_Idx_Box, round_to=int):
        "Extract boxes centers from list of Idx_Box named tuple"
        centers=[]
        for box in tl_dr_Idx_Box:
            if round_to >0:
                centers.append((box.id, [round(box.top_left[0] + 0.5*(box.dx), round_to), round(box.top_left[1] + 0.5*(box.dy) , round_to) ]))
            else:
                centers.append((box.id, [int(box.top_left[0] + 0.5*(box.dx)), int(box.top_left[1] + 0.5*(box.dy)) ]))
        return centers


    def create_big_box_from_ids(self,ids, boxes_data):
        "Merge boxes from id list into a single box"
        to_bound=[]
        for box in boxes_data:
            if getattr(box, 'id') in ids: to_bound.append(box) 
        to_bound.sort(key=lambda a: a.top_left[0])
        TLx=to_bound[0].top_left[0]
        to_bound.sort(key=lambda a: a.top_left[1])
        TLy=to_bound[0].top_left[1]

        to_bound.sort(key=lambda a: a.bottom_right[0])
        BRx=to_bound[-1].bottom_right[0]
        to_bound.sort(key=lambda a: a.bottom_right[1])
        BRy=to_bound[-1].bottom_right[1]

        return [(int(TLx), int(TLy)), (int(BRx), int(BRy))]

# %%
boxes_engine=BoxesEngine()

# %%
boxes_engine.extract_area_of_4boxes_list(list_bboxes=boxes[imgs_paths[0].split('/')[-1]])
# Out:
# 219146.0

# %%
f"Pct area covered by text boxes: {round((boxes_engine.extract_area_of_4boxes_list(boxes[imgs_paths[0].split('/')[-1]]) / (width*height))*100, 2)}%"
# Out:
# 'Pct area covered by text boxes: 18.81%'

# %%
Box = namedtuple("Box", "top_left bottom_right dx dy")
Idx_Box=namedtuple("Idx_Box", "id top_left bottom_right dx dy")

# %%
tldr_boxes={}
n=0
for k, v in boxes.items():
    tldr_boxes[k]=[boxes_engine._4bbox_to_tl_br(box_vertices=box) for box in v]
    
for k, v in tldr_boxes.items():
    for i in range(len(v)):
        v[i]=Idx_Box(i, *v[i])

# %%
b_list=tldr_boxes[imgs_paths[0].split('/')[-1]]

# %%
b_list
# Out:
# [Idx_Box(id=0, top_left=[106.4608383178711, 152.2533416748047], bottom_right=[205.7374267578125, 211.94569396972656], dx=97.27, dy=56.22),
#  Idx_Box(id=1, top_left=[672.38623046875, 153.60951232910156], bottom_right=[884.9794311523438, 213.6461181640625], dx=211.39, dy=55.44),
#  Idx_Box(id=2, top_left=[214.52850341796875, 157.71975708007812], bottom_right=[449.4215087890625, 229.99034118652344], dx=232.27, dy=62.51),
#  Idx_Box(id=3, top_left=[513.0, 165.375], bottom_right=[661.5, 210.9375], dx=148.5, dy=45.56),
#  Idx_Box(id=4, top_left=[459.0, 167.0625], bottom_right=[489.375, 207.5625], dx=30.38, dy=40.5),
#  Idx_Box(id=5, top_left=[377.4471740722656, 241.67909240722656], bottom_right=[469.7883605957031, 304.8788757324219], dx=88.93, dy=57.97),
#  Idx_Box(id=6, top_left=[701.0841674804688, 242.3671112060547], bottom_right=[814.2919921875, 301.048095703125], dx=111.87, dy=56.02),
#  Idx_Box(id=7, top_left=[477.6756896972656, 234.57249450683594], bottom_right=[694.583740234375, 315.852294921875], dx=212.37, dy=66.85),
#  Idx_Box(id=8, top_left=[99.70928192138672, 244.94973754882812], bottom_right=[372.79620361328125, 311.8014221191406], dx=270.66, dy=54.91),
#  Idx_Box(id=9, top_left=[324.0, 332.4375], bottom_right=[448.875, 389.8125], dx=124.88, dy=57.38),
#  Idx_Box(id=10, top_left=[457.3125, 332.4375], bottom_right=[653.0625, 389.8125], dx=195.75, dy=57.38),
#  Idx_Box(id=11, top_left=[99.37387084960938, 323.65252685546875], bottom_right=[318.36175537109375, 405.5360412597656], dx=213.96, dy=65.43),
#  Idx_Box(id=12, top_left=[664.875, 344.25], bottom_right=[698.625, 388.125], dx=33.75, dy=43.88),
#  Idx_Box(id=13, top_left=[713.8125, 344.25], bottom_right=[880.875, 403.3125], dx=167.06, dy=59.06),
#  Idx_Box(id=14, top_left=[101.25, 421.875], bottom_right=[168.75, 479.25], dx=67.5, dy=57.38),
#  Idx_Box(id=15, top_left=[166.57777404785156, 412.0766296386719], bottom_right=[503.61163330078125, 497.730712890625], dx=333.47, dy=68.22),
#  Idx_Box(id=16, top_left=[508.31610107421875, 420.6485900878906], bottom_right=[786.4760131835938, 489.9978332519531], dx=276.12, dy=59.96),
#  Idx_Box(id=17, top_left=[96.75498962402344, 501.54473876953125], bottom_right=[364.1097106933594, 585.6346435546875], dx=263.25, dy=68.26),
#  Idx_Box(id=18, top_left=[374.2137145996094, 511.0424499511719], bottom_right=[651.686279296875, 572.3191528320312], dx=276.97, dy=58.93),
#  Idx_Box(id=19, top_left=[101.25, 605.8125], bottom_right=[357.75, 675.0], dx=256.5, dy=69.19)]

# %% [markdown]
# ### Solution: MeanShift clustering

# %%
clustered_box=namedtuple("clustered_box", "id top_left bottom_right dx dy cluster_id")

# %%
from sklearn.cluster import MeanShift
from collections import Counter, defaultdict

# %%
centers=boxes_engine.tl_br_list_to_centers(b_list, round_to=-1)

# %%
X = np.array([c[1] for c in centers])
clst = MeanShift(bandwidth=None).fit(X)

# %%
cluster_id_to_box_id=list(zip(clst.labels_, [c[0] for c in centers] ))
clustered_boxes = defaultdict(list)
for x in cluster_id_to_box_id:
    clustered_boxes[x[0]].append(x[1])
clustered_boxes_ids=dict(clustered_boxes)

# %%
tl_br_text_boxes=[]
for k, v in clustered_boxes_ids.items():
    tl_br_text_boxes.append(boxes_engine.create_big_box_from_ids(v, tldr_boxes[imgs_paths[0].split('/')[-1]]))

# %%
clustered_boxes_ids[1]
# Out:
# [0, 2, 4, 5, 8, 9]

# %%
def intersects(r1, r2):
    return not (self.top_right.x < other.bottom_left.x or self.bottom_left.x > other.top_right.x or self.top_right.y < other.bottom_left.y or self.bottom_left.y > other.top_right.y)

# %%
tl_br_text_boxes[0]
# Out:
# [(99, 152), (489, 389)]

# %%
union(tl_br_text_boxes[0], tl_br_text_boxes[1])
# Out:
# (374, 153, 884, 572)

# %%
# Showing results
orig_img=cv2.imread(f"./result/res_{imgs_paths[0].split('/')[-1]}")
big_boxes_img=orig_img.copy()
for r in tl_br_text_boxes:
    cv2.rectangle(big_boxes_img, r[0], r[1], (255, 0, 0), 2)
show_cv_to_pil(big_boxes_img)

# %%
f"[enhanced] Pct area covered by text boxes: {boxes_engine.extract_area_of_tl_br_box_list(tl_br_text_boxes)/(600**2)*100}%"
# Out:
# '[enhanced] Pct area covered by text boxes: 124.82888888888888%'

# %% [markdown]
# ### OCR pytesseract

# %%
# TODO
# Understand if there's highlighted text: bold, full-capslock, higher fontsize

# %%
# Big boxes segmentaion

# %%
import pytesseract

# %%
class OcrEngine():
    
    def _preprocess(self,text_box):
        gray = cv2.cvtColor(text_box, cv2.COLOR_BGR2GRAY)
        text_box_gray = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)[1]
        return cv2.medianBlur(gray, 3)

    def reconstruct_text_from_pieces(self, text_boxes, original_image, tolerance=int):
        full_text=''
        for b_ in text_boxes:
            text_box=original_image[b_[0][1]-tolerance: b_[1][1]+tolerance, b_[0][0]-tolerance: b_[1][0]+tolerance]
            # TODO save text boxes to disk?
            # filename = "{}.png".format(os.getpid())
            # cv2.imwrite(filename, gray)
            pr_text_box=self._preprocess(text_box)
            text = pytesseract.image_to_string(pr_text_box)
            full_text+=(''.join(text.replace('\n', ' ').splitlines()))
        return ' '.join(full_text.split())

    def extract_uppers(self, T):
        "Extract list of upper case words from a string of text"
        uppers=[]
        for word in T.split(' '):
            if word.isupper():
                uppers.append(word)
            else:
                continue
        return uppers

# %%
starting_image=cv2.imread('/home/atogni/Desktop/ocr_gradient/test_images/post_imgs/TEST/CH_JQugBNjc_2.jpg')

# %%
ocr_engine=OcrEngine()

# %%
b_=tl_br_text_boxes[1]
tolerance=5
text_box=starting_image[b_[0][1]-tolerance: b_[1][1]+tolerance, b_[0][0]-tolerance: b_[1][0]+tolerance]
show_cv_to_pil(text_box)
gray_text_box=ocr_engine._preprocess(text_box)

# %%
show_cv_to_pil(gray_text_box)

# %%
text = pytesseract.image_to_string(gray_text_box)
print(text)
# Out:
# AFFORDABLE
# ENERGY
#
# to a growing
# population 4

# %%
T=ocr_engine.reconstruct_text_from_pieces(text_boxes=tl_br_text_boxes,original_image=starting_image , tolerance=10)

# %%
T
# Out:
# 'The dual challenge is finding ways to provide AFFORDABLE ENERGY to a growing population He while addressing THE RISKS OF CLIMATE CHANGE'

# %%
ocr_engine.extract_uppers(T)
# Out:
# ['AFFORDABLE', 'ENERGY', 'THE', 'RISKS', 'OF', 'CLIMATE', 'CHANGE']

# %%
# Text on the biggest box ~ most emphasized (?)

# %% [markdown]
# ### Entities extraction

# %%
# ! pip3 install -U spacy
# ! python3 -m spacy download en_core_web_sm
# ! pip3 install https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.0/en_core_web_sm-2.2.0.tar.gz

# %%
import spacy
nlp = spacy.load('en_core_web_lg')

# %%
d=nlp(T)

# %%
features = {}
nouns=[]
for token in d:
    features.append({'token' : token.text, 'pos' : token.pos_})
    if token.pos_=='NOUN':
# Out:
#   Input In [147]
#
#     ^
# SyntaxError: incomplete input

# %%
for token in d.noun_chunks:
    print(token)
# Out:
# The dual challenge
# ways
# AFFORDABLE ENERGY
# a growing population
# THE RISKS
# CLIMATE CHANGE

# %%
! pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-1.4.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 78.9 MB/s eta 0:00:00m eta 0:00:0136m0:00:01
# Requirement already satisfied: pytz>=2020.1 in /home/atogni/anaconda3/envs/gradient_ocr/lib/python3.10/site-packages (from pandas) (2022.1)
# Requirement already satisfied: numpy>=1.21.0 in /home/atogni/anaconda3/envs/gradient_ocr/lib/python3.10/site-packages (from pandas) (1.23.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/atogni/anaconda3/envs/gradient_ocr/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/atogni/anaconda3/envs/gradient_ocr/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Installing collected packages: pandas
# Successfully installed pandas-1.4.3

# %%
import pandas as pd

# %%
df1 = pd.DataFrame({"A":[1,0,1,2,1],"B":[2,2,1,0,1],"C":[1,1,1,2,1],"D":[2,1,2,1,1]})
df2 = pd.DataFrame({"A":[1],"B":[2],"D":[4]})

# %%
df1_cols=df1.columns
df2_cols=df2.columns

# %%
if len(df1_cols) > len(df2_cols):
    for c in df1_cols:
        if c in df1_cols & c in df2_cols:
